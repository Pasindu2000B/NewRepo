# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection

# %%
import pandas as pd

import pandas as pd

# Use a raw string for the file path
file_path = r'C:\Users\Asus\Downloads\train-titanic.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df.head()

df = pd.read_csv(file_path)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(["Ticket"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
dummy=pd.get_dummies(df[["Sex","Embarked"]])

# %%
dummy.drop(["Sex_female","Embarked_C"],axis=1,inplace=True)

# %%
dummy.head()
# Out:
#    Sex_male  Embarked_Q  Embarked_S
# 0         1           0           1
# 1         0           0           0
# 2         0           0           1
# 3         0           0           1
# 4         1           0           1

# %%
df_new=pd.concat([dummy,df],axis=1)

# %%
df_new.head()
# Out:
#    Sex_male  Embarked_Q  Embarked_S  Survived  Pclass     Sex   Age  SibSp  \
# 0         1           0           1         0       3    male  22.0      1
# 1         0           0           0         1       1  female  38.0      1
# 2         0           0           1         1       3  female  26.0      0
# 3         0           0           1         1       1  female  35.0      1
# 4         1           0           1         0       3    male  35.0      0
#
#    Parch     Fare    Cabin Embarked
# 0      0   7.2500  B96 B98        S
# 1      0  71.2833      C85        C
# 2      0   7.9250  B96 B98        S
# 3      0  53.1000     C123        S
# 4      0   8.0500  B96 B98        S

# %%
df_new.drop(["Sex","Embarked","Cabin"],axis=1,inplace=True)

# %%
df_new.head()
# Out:
#    Sex_male  Embarked_Q  Embarked_S  Survived  Pclass   Age  SibSp  Parch  \
# 0         1           0           1         0       3  22.0      1      0
# 1         0           0           0         1       1  38.0      1      0
# 2         0           0           1         1       3  26.0      0      0
# 3         0           0           1         1       1  35.0      1      0
# 4         1           0           1         0       3  35.0      0      0
#
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assuming you have already loaded the dataset into a DataFrame called df
# Selecting features
X = df_new[['Sex_male', 'Embarked_Q', 'Embarked_S', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]

# Selecting target variable
y = df_new['Survived']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=4)
from sklearn.linear_model import LinearRegression
linReg = LinearRegression()
linReg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 5
#       3 from sklearn.linear_model import LinearRegression
#       4 linReg = LinearRegression()
# ----> 5 linReg.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...
